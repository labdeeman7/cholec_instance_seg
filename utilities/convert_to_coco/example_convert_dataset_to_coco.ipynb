# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('../..')

# %% [markdown]
# ## Convert from my annotation to COCO

# %%
from utils.convert_to_coco_utils.convert_dataset_to_coco_utils import annotations_to_coco

# %%
split = 'val'
dataset_path = f"C:/Users/tal22/Documents/repositories/generate_binary_and_instance_masks_for_cholecseg8k/datasets/final_cholecinstanceseg/{split}"
output_json_path = f"C:/Users/tal22/Documents/repositories/generate_binary_and_instance_masks_for_cholecseg8k/datasets/final_cholecinstanceseg/{split}_coco_annotations.json"
annotations_to_coco(dataset_path, output_json_path, False)
# Out:
# currently on 0, seg8k_video17_001563.png, mask seg8k_video17_001563.json
# currently on 1, seg8k_video17_001564.png, mask seg8k_video17_001564.json
# currently on 2, seg8k_video17_001565.png, mask seg8k_video17_001565.json
# currently on 3, seg8k_video17_001566.png, mask seg8k_video17_001566.json
# currently on 4, seg8k_video17_001567.png, mask seg8k_video17_001567.json
# currently on 5, seg8k_video17_001568.png, mask seg8k_video17_001568.json
# currently on 6, seg8k_video17_001569.png, mask seg8k_video17_001569.json
# currently on 7, seg8k_video17_001570.png, mask seg8k_video17_001570.json
# currently on 8, seg8k_video17_001571.png, mask seg8k_video17_001571.json
# currently on 9, seg8k_video17_001572.png, mask seg8k_video17_001572.json
# currently on 10, seg8k_video17_001573.png, mask seg8k_video17_001573.json
# currently on 11, seg8k_video17_001574.png, mask seg8k_video17_001574.json
# currently on 12, seg8k_video17_001575.png, mask seg8k_video17_001575.json
# ...
